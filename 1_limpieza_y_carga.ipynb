# %%
import pandas as pd
import os

# Changing the directory to the parent directory
os.chdir('C:/Users/User/Platzi/Curso para crear tus proyectos en ciencia de datos')

# %%
# List the content in the current directory
# !dir
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: A277-AB13
#
#  Directorio de C:\Users\User\Platzi\Curso para crear tus proyectos en ciencia de datos
#
# 03/05/2024  18:38    <DIR>          .
# 03/05/2024  18:38    <DIR>          ..
# 03/05/2024  18:28    <DIR>          .ipynb_checkpoints
# 03/05/2024  18:26           189.110 12_DICIEMBRE_2020.xlsx
# 03/05/2024  18:38            11.842 1_limpieza_y_carga.ipynb
#                2 archivos        200.952 bytes
#                3 dirs  345.967.665.152 bytes libres

# %%
pip install --upgrade openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\user\anaconda3\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\user\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Reading different Excel files into dataframes
df_gastos_varios = pd.read_excel('12_DICIEMBRE_2020.xlsx', sheet_name='GASTOS VARIOS', skiprows=5)
df_contratistas = pd.read_excel('12_DICIEMBRE_2020.xlsx', sheet_name='CONTRATISTAS Y FDO FED', skiprows=5)
df_servicios = pd.read_excel('12_DICIEMBRE_2020.xlsx', sheet_name='SERV PPROF', skiprows=5)
df_comunicacion = pd.read_excel('12_DICIEMBRE_2020.xlsx', sheet_name='COMUNICACION', skiprows=5)
df_personales= pd.read_excel('12_DICIEMBRE_2020.xlsx', sheet_name='SERV. PERS.', skiprows=5)
# Adding a 'SHEET' column to each dataframe to indicate the source sheet
df_gastos_varios['SHEET'] = 'GASTOS VARIOS'
df_contratistas['SHEET'] = 'CONTRATISTAS Y FDO FED'
df_servicios['SHEET'] = 'SERV PPROF'
df_comunicacion['SHEET'] = 'COMUNICACION'
df_personales['SHEET'] = 'SERV. PERS.'

df_compras_dic=pd.concat([df_gastos_varios,df_contratistas,df_servicios, df_comunicacion,df_personales])
df_compras_dic
# Out:
#          NUM BEN                                    BENEFICIARIO  \
# 0         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 1         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 2         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 3         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 4         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# ..           ...                                             ...
# 43        203016                            SEGOVIA PAEZ MARCELO
# 44        203016                    TORRES ACOSTA ROBERTO CARLOS
# 45        203016                    TOVAR CEDILLO JAVIER ALFONSO
# 46        203016                VILLARREAL CARDENAS NANCY ESTHER
# 47  Total 203016                                             NaN
#
#               RFC                 FACTURA      CONTRATO  \
# 0    LSS841015DV3  LLS AF8458-158008-3972  OT. 20204373
# 1    LSS841015DV3  LLS PF6916-158008-4041  OT. 20204425
# 2    LSS841015DV3  LLS PF6917-158008-3975  OT. 20204376
# 3    LSS841015DV3  LLS PF7004-158008-3971  OT. 20204374
# 4    LSS841015DV3  LLS PF7137-158008-4554  OT. 20205130
# ..            ...                     ...           ...
# 43  SEPM8603058S7      116033-158004-1690     NO APLICA
# 44  TOAR8409234Y0      113052-158004-1725     NO APLICA
# 45  TOCJ750710A31       23016-158004-1705     NO APLICA
# 46  VICN801211SM7      113711-158004-1711     NO APLICA
# 47            NaN                     NaN           NaN
#
#                                              CONCEPTO TIPO         # OP  \
# 0   REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR    1019110.0
# 1   REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR    1019110.0
# 2   REEMPLAZO DE DOS RINES  (17). PATRIMONIO 80383...   TR    1019110.0
# 3   REEMPLAZO DE  DOS RINES  (14). PATRIMONIO 8007...   TR    1019110.0
# 4   REEMPLAZO E INSTALACION DE RIN 14. PATRIMONIO ...   TR  299001496.0
# ..                                                ...  ...          ...
# 43                             FONDO PENSIONES 116033   CH    1104571.0
# 44                          FONDO DE PENSIONES 113052   CH  299000183.0
# 45  PAGO 30%  JUICIO DE AMPARO No. 673/2020 (DICIE...   CH  299000179.0
# 46                             FONDO PENSIONES 113711   CH    1104567.0
# 47                                                NaN  NaN          NaN
#
#         FECHA    IMPORTE          SHEET
# 0  2020-12-11   14911.80  GASTOS VARIOS
# 1  2020-12-11    2528.80  GASTOS VARIOS
# 2  2020-12-11    8500.02  GASTOS VARIOS
# 3  2020-12-11    2400.01  GASTOS VARIOS
# 4  2020-12-23    1537.00  GASTOS VARIOS
# ..        ...        ...            ...
# 43 2020-12-11   56430.00    SERV. PERS.
# 44 2020-12-16    7425.00    SERV. PERS.
# 45 2020-12-15    4084.68    SERV. PERS.
# 46 2020-12-11   22575.00    SERV. PERS.
# 47        NaT  794510.08    SERV. PERS.
#
# [1774 rows x 11 columns]

# %%
len(df_compras_dic)
# Out:
# 1774

# %%
df_compras_dic_com=df_compras_dic.dropna(how='any')

# %%
len(df_compras_dic_com)
# Out:
# 1540

# %%
df_compras_dic_com.dtypes
# Out:
# NUM BEN                 object
# BENEFICIARIO            object
# RFC                     object
# FACTURA                 object
# CONTRATO                object
# CONCEPTO                object
# TIPO                    object
# # OP                   float64
# FECHA           datetime64[ns]
# IMPORTE                float64
# SHEET                   object
# dtype: object

# %%
df_compras_dic_com['FECHA'].apply(lambda x: x.month).value_counts()
# Out:
# FECHA
# 12    1540
# Name: count, dtype: int64

# %%
df_compras_dic_com.head()
# Out:
#   NUM BEN                                    BENEFICIARIO           RFC  \
# 0  110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 1  110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 2  110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 3  110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 4  110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
#
#                   FACTURA      CONTRATO  \
# 0  LLS AF8458-158008-3972  OT. 20204373
# 1  LLS PF6916-158008-4041  OT. 20204425
# 2  LLS PF6917-158008-3975  OT. 20204376
# 3  LLS PF7004-158008-3971  OT. 20204374
# 4  LLS PF7137-158008-4554  OT. 20205130
#
#                                             CONCEPTO TIPO         # OP  \
# 0  REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR    1019110.0
# 1  REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR    1019110.0
# 2  REEMPLAZO DE DOS RINES  (17). PATRIMONIO 80383...   TR    1019110.0
# 3  REEMPLAZO DE  DOS RINES  (14). PATRIMONIO 8007...   TR    1019110.0
# 4  REEMPLAZO E INSTALACION DE RIN 14. PATRIMONIO ...   TR  299001496.0
#
#        FECHA   IMPORTE          SHEET
# 0 2020-12-11  14911.80  GASTOS VARIOS
# 1 2020-12-11   2528.80  GASTOS VARIOS
# 2 2020-12-11   8500.02  GASTOS VARIOS
# 3 2020-12-11   2400.01  GASTOS VARIOS
# 4 2020-12-23   1537.00  GASTOS VARIOS

# %%
df_compras_dic_com.to_csv("C:/Users/User/Platzi/Curso para crear tus proyectos en ciencia de datos/data/clean_compras.csv",index=None)
